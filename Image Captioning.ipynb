# %%
from image_captioning import *

# %%
image_path = 'fallout.jpeg'
image = Image.open(image_path)
plt.imshow(np.asarray(image))
plt.show()

# %%
image_path = 'cruise.jpeg'
image = Image.open(image_path)
plt.imshow(np.asarray(image))
plt.show()

# %% [markdown]
# The code has been adapted from
# https://github.com/yunjey/pytorch-tutorial/tree/master/tutorials/03-advanced/image_captioning
#
# We have however made several changes to it and we are in the process of restructuring it further to suit our own class hierarchy

# %%
captioner = ImageCaptioning()

# %%
sentence,caption_embedding,image_ = captioner.get_caption(image)
# Out:
#  a man riding a motorcycle on a street .

# %% [markdown]
# ## Similar Images Use Case

# %% [markdown]
# We have pre-converted all the captions in our dataset to embedding vectors using the same embeddings that we trained on. Because we have memory limitations, we are using only 50000 images from COCO dataset.
#
# After that we find the k-most similar images to the given images using KNN

# %%
captioner.set_up_embeddings(knn_path='similar/knn_captions_model.joblib')

# %% [markdown]
# Next we find similar images by comparing embedding vectors of captions with the emebedding vector of the predicted caption. We use KNN for comparing embeddings and finding k-similar images. Here I have fixed k to 5 for now but will change it when I structure my API properly

# %%
imgs,captions,fig = captioner.get_similar_images(image)
# Out:
#  a man riding a motorcycle on a street .

# %%
# captioner.set_up_KNN(5)
